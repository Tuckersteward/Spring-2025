# %% [markdown]
# # ICE: Sources of Data
# ## Name: Cabot
# ## *DATA 3300*
#
# In this in-class exercise we will examine different ways that we can source data, beginning with precompiled datasets, followed by web APIs, and then finally we will produce our own dataset from a class survey.

# %% [markdown]
# Whenever I am working on putting together a dataset, I do so with the intention of solving a particular problem or answering a particular question. This will guide what data I need to source!
#
# **So, let's say we're starting a Travel Agency business to help individuals plan optimal trips to National Parks, what sort of data might we want to make data-driven recommendations?**

# %% [markdown]
# *  customer level data - primary data collection - survey
# *  park level data - secondary data

# %% [markdown]
# ## **Part A) Primary Data Collection**
#
# Surveys are one common way of collecting data, and it can be a helpful way for gathering information from specific individuals. Let's [create a survey](https://docs.google.com/forms/u/0/) with five or so questions we think will help us plan a National Parks Holiday trip!
#
# These questions should help us narrow down their preferences around:
#
#
#
# *   Region of the country to visit
# *   Preference around traffic
# *   Type of sites preferred
# *   Trail activity type preference
# *   Weather preferences

# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %% [markdown]
# ## **Part B) Secondary Data Collection**
#
# Let's begin with examining some sources of precompiled datasets. Websites I often use for sourcing datasets include:
#
# *   Government websites, like [Transparent Utah](https://transparent.utah.gov/job_title_search.php)
# *   [Kaggle](https://www.kaggle.com/datasets)
# *   [Data is Plural](https://www.data-is-plural.com/archive/)
#
# Let's see what precompiled data is out there that might be useful related to finding info on national parks!

# %% [markdown]
# [National Parks Dataset](https://www.kaggle.com/datasets/thedevastator/the-united-states-national-parks?select=df_2.csv)
#
# [National Park Trails](https://www.data-is-plural.com/archive/2020-08-26-edition/)

# %%
parks = pd.read_csv('df_2.csv') # load in data set
parks.head()
# Out:
#    Unnamed: 0            Name  Image  \
# 0           0          Acadia    NaN
# 1           1  American Samoa    NaN
# 2           2          Arches    NaN
# 3           3        Badlands    NaN
# 4           4        Big Bend    NaN
#
#                                             Location  \
# 0  Maine.mw-parser-output .geo-default,.mw-parser...
# 1  American Samoa14°15′S 170°41′W﻿ / ﻿14.25°S 170...
# 2          Utah38°41′N 109°34′W﻿ / ﻿38.68°N 109.57°W
# 3  South Dakota43°45′N 102°30′W﻿ / ﻿43.75°N 102.50°W
# 4         Texas29°15′N 103°15′W﻿ / ﻿29.25°N 103.25°W
#
#   Date established as park[7][12]                 Area (2021)[13]  \
# 0                       26-Feb-19     49,071.40 acres (198.6 km2)
# 1                       31-Oct-88       8,256.67 acres (33.4 km2)
# 2                       12-Nov-71     76,678.98 acres (310.3 km2)
# 3                       10-Nov-78    242,755.94 acres (982.4 km2)
# 4                       12-Jun-44  801,163.21 acres (3,242.2 km2)
#
#    Recreation visitors (2021)[11]  \
# 0                         4069098
# 1                            8495
# 2                         1806865
# 3                         1224226
# 4                          581220
#
#                                          Description
# 0  Covering most of Mount Desert Island and other...
# 1  The southernmost national park is on three Sam...
# 2  This site features more than 2,000 natural san...
# 3  The Badlands are a collection of buttes, pinna...
# 4  Named for the prominent bend in the Rio Grande...

# %% [markdown]
# **1) Narrow Down the Dataset: Let's filter down this dataset some to parks of interest based on their Location -- Assume we want to stick to locations in the Intermountain West. How can we use the Location columns to narrow down our list?**

# %%
# filtered_parks = parks[parks['Location'].str.startswith(('Utah', 'Colorado', 'Wyoming', 'Montana', 'Idaho', 'Arizona'))] # add in strings to filter down location
filtered_parks = parks[parks['Location'].str.contains('Utah|Colorado|Wyoming|Montana|Idaho|Arizona', case=False)]
filtered_parks.head()
# Out:
#    Unnamed: 0                          Name  Image  \
# 2           2                        Arches    NaN
# 6           6  Black Canyon of the Gunnison    NaN
# 7           7                  Bryce Canyon    NaN
# 8           8                   Canyonlands    NaN
# 9           9                  Capitol Reef    NaN
#
#                                         Location  \
# 2      Utah38°41′N 109°34′W﻿ / ﻿38.68°N 109.57°W
# 6  Colorado38°34′N 107°43′W﻿ / ﻿38.57°N 107.72°W
# 7      Utah37°34′N 112°11′W﻿ / ﻿37.57°N 112.18°W
# 8       Utah38°12′N 109°56′W﻿ / ﻿38.2°N 109.93°W
# 9      Utah38°12′N 111°10′W﻿ / ﻿38.20°N 111.17°W
#
#   Date established as park[7][12]                 Area (2021)[13]  \
# 2                       12-Nov-71     76,678.98 acres (310.3 km2)
# 6                       21-Oct-99     30,779.83 acres (124.6 km2)
# 7                       25-Feb-28     35,835.08 acres (145.0 km2)
# 8                       12-Sep-64  337,597.83 acres (1,366.2 km2)
# 9                       18-Dec-71    241,904.50 acres (979.0 km2)
#
#    Recreation visitors (2021)[11]  \
# 2                         1806865
# 6                          308910
# 7                         2104600
# 8                          911594
# 9                         1405353
#
#                                          Description
# 2  This site features more than 2,000 natural san...
# 6  The park protects a quarter of the Gunnison Ri...
# 7  Bryce Canyon is a geological amphitheater on s...
# 8  This landscape was eroded into a maze of canyo...
# 9  The park's Waterpocket Fold is a 100-mile (160...

# %%
# view the parks within those locations
filtered_parks['Name'].value_counts()
# Out:
# Name
# Arches                          1
# Black Canyon of the Gunnison    1
# Bryce Canyon                    1
# Canyonlands                     1
# Capitol Reef                    1
# Glacier                         1
# Grand Canyon *                  1
# Grand Teton                     1
# Great Sand Dunes                1
# Mesa Verde *                    1
# Petrified Forest                1
# Rocky Mountain                  1
# Saguaro                         1
# Yellowstone                     1
# Zion                            1
# Name: count, dtype: int64

# %% [markdown]
# **2) If we know our customer is interested in specific geographic sites or types of sites, how can we further filter down parks?**

# %% [markdown]
# see desc_filter variable below

# %%
mountain_parks = filtered_parks[filtered_parks['Description'].str.contains('mountain', case=False)] # add in description, why are we using contains here instead of startsiwth?
mountain_parks
# Out:
#     Unnamed: 0              Name  Image  \
# 21          21           Glacier    NaN
# 24          24       Grand Teton    NaN
# 26          26  Great Sand Dunes    NaN
# 50          50    Rocky Mountain    NaN
# 51          51           Saguaro    NaN
# 60          60       Yellowstone    NaN
#
#                                          Location  \
# 21   Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 24   Wyoming43°44′N 110°48′W﻿ / ﻿43.73°N 110.80°W
# 26  Colorado37°44′N 105°31′W﻿ / ﻿37.73°N 105.51°W
# 50  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 51   Arizona32°15′N 110°30′W﻿ / ﻿32.25°N 110.50°W
# 60                        Wyoming, Montana, Idaho
#
#    Date established as park[7][12]                   Area (2021)[13]  \
# 21                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 24                       26-Feb-29    310,044.36 acres (1,254.7 km2)
# 26                       24-Sep-04      107,345.73 acres (434.4 km2)
# 50                       26-Jan-15    265,807.24 acres (1,075.7 km2)
# 51                       14-Oct-94       92,867.42 acres (375.8 km2)
# 60                   March 1, 1872  2,219,790.71 acres (8,983.2 km2)
#
#     Recreation visitors (2021)[11]  \
# 21                         3081656
# 24                         3885230
# 26                          602613
# 50                         4434848
# 51                         1079786
# 60                         4860242
#
#                                           Description
# 21  The U.S. half of Waterton-Glacier Internationa...
# 24  Grand Teton is the tallest mountain in the sce...
# 26  The tallest sand dunes in North America, up to...
# 50  Bisected north to south by the Continental Div...
# 51  Split into the separate Rincon Mountain and Tu...
# 60  Situated on the Yellowstone Caldera, the park ...

# %%
mountain_parks['Name'].value_counts() # check the parks count
# Out:
# Name
# Glacier             1
# Grand Teton         1
# Great Sand Dunes    1
# Rocky Mountain      1
# Saguaro             1
# Yellowstone         1
# Name: count, dtype: int64

# %% [markdown]
# **3) Now let's Incorporate our Trail Data! What pieces of information tie together these two datasets?**

# %%
pd.set_option('display.max_columns', None)

# %%
trails = pd.read_csv('NPS_-_Trails_-_Geographic_Coordinate_System.csv') # read in second dataset
trails.head()
# Out:
#    OBJECTID           TRLNAME TRLALTNAME          MAPLABEL TRLSTATUS  \
# 0         1  Jumbo Mine Trail        NaN  Jumbo Mine Trail  Existing
# 1         2  Jumbo Mine Trail        NaN  Jumbo Mine Trail  Existing
# 2         3  Jumbo Mine Trail        NaN  Jumbo Mine Trail  Existing
# 3         4  Jumbo Mine Trail        NaN  Jumbo Mine Trail  Existing
# 4         5  Jumbo Mine Trail        NaN  Jumbo Mine Trail  Existing
#
#   TRLSURFACE               TRLTYPE                       TRLCLASS  \
# 0    Unknown  Standard Terra Trail  Class 2: Moderately Developed
# 1    Unknown  Standard Terra Trail  Class 2: Moderately Developed
# 2    Unknown  Standard Terra Trail  Class 2: Moderately Developed
# 3    Unknown  Standard Terra Trail  Class 2: Moderately Developed
# 4    Unknown  Standard Terra Trail  Class 2: Moderately Developed
#
#              TRLUSE       PUBLICDISPLAY    DATAACCESS  ACCESSNOTES ORIGINATOR  \
# 0  Hiker/Pedestrian  Public Map Display  Unrestricted          NaN        NaN
# 1  Hiker/Pedestrian  Public Map Display  Unrestricted          NaN        NaN
# 2  Hiker/Pedestrian  Public Map Display  Unrestricted          NaN        NaN
# 3  Hiker/Pedestrian  Public Map Display  Unrestricted          NaN        NaN
# 4  Hiker/Pedestrian  Public Map Display  Unrestricted          NaN        NaN
#
#   UNITCODE                                      UNITNAME UNITTYPE GROUPCODE  \
# 0     WRST  Wrangell-St Elias National Park and Preserve      NaN       NaN
# 1     WRST  Wrangell-St Elias National Park and Preserve      NaN       NaN
# 2     WRST  Wrangell-St Elias National Park and Preserve      NaN       NaN
# 3     WRST  Wrangell-St Elias National Park and Preserve      NaN       NaN
# 4     WRST  Wrangell-St Elias National Park and Preserve      NaN       NaN
#
#   GROUPNAME REGIONCODE              CREATEDATE                EDITDATE  \
# 0       NaN        AKR  2015/07/06 23:52:35+00  2018/03/21 16:35:19+00
# 1       NaN        AKR  2015/07/06 23:52:35+00  2018/03/21 16:35:19+00
# 2       NaN        AKR  2015/07/06 23:52:35+00  2018/03/21 16:35:19+00
# 3       NaN        AKR  2015/07/06 23:52:35+00  2018/03/21 16:35:19+00
# 4       NaN        AKR  2015/07/06 23:52:35+00  2018/03/21 16:35:19+00
#
#       LINETYPE MAPMETHOD                                          MAPSOURCE  \
# 0  Center line     Other  Various Source data compiled by Joshua Scott w...
# 1  Center line     Other  Various Source data compiled by Joshua Scott w...
# 2  Center line     Other  Various Source data compiled by Joshua Scott w...
# 3  Center line     Other  Various Source data compiled by Joshua Scott w...
# 4  Center line     Other  Various Source data compiled by Joshua Scott w...
#
#   SOURCEDATE XYACCURACY                              GEOMETRYID  \
# 0        NaN    Unknown  {D0CB98B0-92A1-4CAC-AFAA-22B12A3DBB7A}
# 1        NaN    Unknown  {3592F079-DA23-4BB7-9412-3BD5379CCB6E}
# 2        NaN    Unknown  {F3ED601E-3020-409A-82D1-DF0A873CD95D}
# 3        NaN    Unknown  {CA60A364-28FE-45D6-AAB5-AC3A0F19505A}
# 4        NaN    Unknown  {B2596ACC-5802-4797-959F-71E3F3586AA1}
#
#                                 FEATUREID FACLOCID FACASSETID IMLOCID  \
# 0  {057D6DDC-BC88-47F4-B444-EAE25ED0CA40}    60670        NaN     NaN
# 1  {057D6DDC-BC88-47F4-B444-EAE25ED0CA40}    60670        NaN     NaN
# 2  {057D6DDC-BC88-47F4-B444-EAE25ED0CA40}    60670        NaN     NaN
# 3  {057D6DDC-BC88-47F4-B444-EAE25ED0CA40}    60670        NaN     NaN
# 4  {057D6DDC-BC88-47F4-B444-EAE25ED0CA40}    60670        NaN     NaN
#
#   OBSERVABLE ISEXTANT OPENTOPUBLIC  ALTLANGNAME  ALTLANG SEASONAL SEASDESC  \
# 0    Unknown     True      Unknown          NaN      NaN  Unknown      NaN
# 1    Unknown     True      Unknown          NaN      NaN  Unknown      NaN
# 2    Unknown     True      Unknown          NaN      NaN  Unknown      NaN
# 3    Unknown     True      Unknown          NaN      NaN  Unknown      NaN
# 4    Unknown     True      Unknown          NaN      NaN  Unknown      NaN
#
#               MAINTAINER             NOTES  \
# 0  National Park Service  Multiple  Routes
# 1  National Park Service  Multiple  Routes
# 2  National Park Service  Multiple  Routes
# 3  National Park Service  Multiple  Routes
# 4  National Park Service  Multiple  Routes
#
#                             StagingTable  ShapeSTLength
# 0  STAGING_AKR_TRAILS_ALL_20240213004113       0.000682
# 1  STAGING_AKR_TRAILS_ALL_20240213004113       0.000259
# 2  STAGING_AKR_TRAILS_ALL_20240213004113       0.000264
# 3  STAGING_AKR_TRAILS_ALL_20240213004113       0.000934
# 4  STAGING_AKR_TRAILS_ALL_20240213004113       0.000281

# %% [markdown]
# **4) Join the datasets by mapping Name to Unitcode then joining on the same primary key!**

# %%
parks_nps_codes = {
    "Glacier": "GLAC",
    "Grand Teton": "GRTE",
    "Great Sand Dunes": "GRSA",
    "Rocky Mountain": "ROMO",
    "Saguaro": "SAGU",
    "Yellowstone": "YELL"
}

# Rename the 'Name' column to 'UNITCODE' and replace values using parks_nps_codes
mountain_parks = mountain_parks.rename(columns={'Name': 'UNITCODE'}) # fill in rename argument
# we really should keep the name column as it provides a lot of information...  
# it would be super simple to just create a new column

mountain_parks['UNITCODE'] = mountain_parks['UNITCODE'].replace(parks_nps_codes) # fill in replace argument
mountain_parks.head()
# Out:
#     Unnamed: 0 UNITCODE  Image                                       Location  \
# 21          21     GLAC    NaN   Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 24          24     GRTE    NaN   Wyoming43°44′N 110°48′W﻿ / ﻿43.73°N 110.80°W
# 26          26     GRSA    NaN  Colorado37°44′N 105°31′W﻿ / ﻿37.73°N 105.51°W
# 50          50     ROMO    NaN  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 51          51     SAGU    NaN   Arizona32°15′N 110°30′W﻿ / ﻿32.25°N 110.50°W
#
#    Date established as park[7][12]                   Area (2021)[13]  \
# 21                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 24                       26-Feb-29    310,044.36 acres (1,254.7 km2)
# 26                       24-Sep-04      107,345.73 acres (434.4 km2)
# 50                       26-Jan-15    265,807.24 acres (1,075.7 km2)
# 51                       14-Oct-94       92,867.42 acres (375.8 km2)
#
#     Recreation visitors (2021)[11]  \
# 21                         3081656
# 24                         3885230
# 26                          602613
# 50                         4434848
# 51                         1079786
#
#                                           Description
# 21  The U.S. half of Waterton-Glacier Internationa...
# 24  Grand Teton is the tallest mountain in the sce...
# 26  The tallest sand dunes in North America, up to...
# 50  Bisected north to south by the Continental Div...
# 51  Split into the separate Rincon Mountain and Tu...

# %%
print(len(trails))
print(len(mountain_parks))
# Out:
# 30527
# 6

# %%
merged_df = pd.merge(mountain_parks, trails, on='UNITCODE', how='inner')# create new dataframe by merging mountain_parks and trails
merged_df.head()
# Out:
#    Unnamed: 0 UNITCODE  Image                                      Location  \
# 0          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 1          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 2          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 3          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 4          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
#
#   Date established as park[7][12]                   Area (2021)[13]  \
# 0                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 1                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 2                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 3                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 4                       11-May-10  1,013,126.39 acres (4,100.0 km2)
#
#    Recreation visitors (2021)[11]  \
# 0                         3081656
# 1                         3081656
# 2                         3081656
# 3                         3081656
# 4                         3081656
#
#                                          Description  OBJECTID  \
# 0  The U.S. half of Waterton-Glacier Internationa...       359
# 1  The U.S. half of Waterton-Glacier Internationa...       365
# 2  The U.S. half of Waterton-Glacier Internationa...       369
# 3  The U.S. half of Waterton-Glacier Internationa...       399
# 4  The U.S. half of Waterton-Glacier Internationa...       406
#
#                         TRLNAME TRLALTNAME                      MAPLABEL  \
# 0                  Quartz Creek        NaN                  Quartz Creek
# 1                Martha's Basin        NaN                Martha's Basin
# 2                   Piegan Pass        NaN                   Piegan Pass
# 3    North Shore Josephine Lake        NaN    North Shore Josephine Lake
# 4  Boulder Pass Campground Spur        NaN  Boulder Pass Campground Spur
#
#   TRLSTATUS TRLSURFACE               TRLTYPE            TRLCLASS  \
# 0  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 1  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 2  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 3  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 4  Existing      Earth  Standard Terra Trail  Class 3: Developed
#
#                                               TRLUSE       PUBLICDISPLAY  \
# 0                 Low Use / Low level of maintenance  Public Map Display
# 1  Moderate to High Use / Highest level of mainte...  Public Map Display
# 2  Moderate to High Use / Highest level of mainte...  Public Map Display
# 3  Moderate to High Use / Highest level of mainte...  Public Map Display
# 4  Moderate to High Use / Highest level of mainte...  Public Map Display
#
#      DATAACCESS  ACCESSNOTES ORIGINATOR               UNITNAME UNITTYPE  \
# 0  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 1  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 2  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 3  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 4  Unrestricted          NaN        NaN  Glacier National Park      NaN
#
#   GROUPCODE GROUPNAME REGIONCODE              CREATEDATE  \
# 0       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 1       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 2       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 3       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 4       NaN       NaN        IMR  2021/04/07 20:22:17+00
#
#                  EDITDATE     LINETYPE MAPMETHOD          MAPSOURCE  \
# 0  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 1  2021/08/06 19:51:05+00  Center line   Unknown         Garmin GPS
# 2  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 3  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 4  2021/08/06 19:51:05+00  Center line   Unknown  ESRI Imagery 2013
#
#   SOURCEDATE XYACCURACY                              GEOMETRYID FEATUREID  \
# 0        NaN    Unknown  {21BA9C26-62D8-49CB-8FFF-81229CC78E52}       NaN
# 1        NaN    Unknown  {0605BD1D-70C4-4D96-AA3F-03168D68A102}       NaN
# 2        NaN    Unknown  {8FEC488C-33AC-4BDA-BBF6-27E4A421C01F}       NaN
# 3        NaN    Unknown  {F11E64B8-0023-4FDE-AB19-7D5752721FA6}       NaN
# 4        NaN    Unknown  {55EA0D6E-8F38-41BC-A87A-273F4D4FAA6E}       NaN
#
#   FACLOCID FACASSETID IMLOCID OBSERVABLE ISEXTANT OPENTOPUBLIC  ALTLANGNAME  \
# 0      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 1      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 2      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 3      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 4      NaN        NaN     NaN    Unknown     True      Unknown          NaN
#
#    ALTLANG SEASONAL SEASDESC             MAINTAINER NOTES  \
# 0      NaN  Unknown      NaN  National Park Service   NaN
# 1      NaN  Unknown      NaN  National Park Service   NaN
# 2      NaN  Unknown      NaN  National Park Service   NaN
# 3      NaN  Unknown      NaN  National Park Service   NaN
# 4      NaN  Unknown      NaN  National Park Service   NaN
#
#                             StagingTable  ShapeSTLength
# 0  STAGING_IMR_TRAILS_ALL_20240213004910       0.120064
# 1  STAGING_IMR_TRAILS_ALL_20240213004910       0.016570
# 2  STAGING_IMR_TRAILS_ALL_20240213004910       0.013829
# 3  STAGING_IMR_TRAILS_ALL_20240213004910       0.006610
# 4  STAGING_IMR_TRAILS_ALL_20240213004910       0.002319

# %%
# view all columns in merged_df
merged_df.columns
# Out:
# Index(['Unnamed: 0', 'UNITCODE', 'Image', 'Location',
#        'Date established as park[7][12]', 'Area (2021)[13]',
#        'Recreation visitors (2021)[11]', 'Description', 'OBJECTID', 'TRLNAME',
#        'TRLALTNAME', 'MAPLABEL', 'TRLSTATUS', 'TRLSURFACE', 'TRLTYPE',
#        'TRLCLASS', 'TRLUSE', 'PUBLICDISPLAY', 'DATAACCESS', 'ACCESSNOTES',
#        'ORIGINATOR', 'UNITNAME', 'UNITTYPE', 'GROUPCODE', 'GROUPNAME',
#        'REGIONCODE', 'CREATEDATE', 'EDITDATE', 'LINETYPE', 'MAPMETHOD',
#        'MAPSOURCE', 'SOURCEDATE', 'XYACCURACY', 'GEOMETRYID', 'FEATUREID',
#        'FACLOCID', 'FACASSETID', 'IMLOCID', 'OBSERVABLE', 'ISEXTANT',
#        'OPENTOPUBLIC', 'ALTLANGNAME', 'ALTLANG', 'SEASONAL', 'SEASDESC',
#        'MAINTAINER', 'NOTES', 'StagingTable', 'ShapeSTLength'],
#       dtype='object')

# %% [markdown]
# **5) What has changed about the structure of the dataset? (Apart from adding new columns from the join)?**

# %% [markdown]
# * we may be "missing" data if it wasn't in both tables
# * we have established a one to many relationship i.e. trail level information

# %% [markdown]
# # **Part C) OpenWeatherMaps API - Let's Check the Forecast at our Parks of Interest!**

# %% [markdown]
# To access the OpenWeatherMap API, first navigate [here](https://openweathermap.org/api) and sign up for an account!
#
# Then we will navigate to the `My API Keys` page under your profile, to generate an API key. This is all we need (aprt from the request/endpoint) to start pulling data from this website!

# %% [markdown]
# **1) Store API Credentials**
#
# Note: This isn't a great way to do this. But since this is a free account we're not too worried about security.

# %%
# API Key (replace 'your_api_key' with the actual API key)
api_key = '42e919afac4c1f87a02bbbff6fab2f54' #9c9681d1ee3a680fd15053968fa4c0a5'

# %% [markdown]
# **2) Set up your request!**
#
# Here, the goal is to add the average temperature for each of our six parks into our dataset, using the Openweather maps API.

# %%
parks_info = {
    "GLAC": {"lat": 48.6966, "lon": -113.7183},
    "GRTE": {"lat": 43.7904, "lon": -110.6818},
    "GRSA": {"lat": 37.7926, "lon": -105.5943},
    "ROMO": {"lat": 40.3428, "lon": -105.6836},
    "SAGU": {"lat": 32.2967, "lon": -111.1666},
    "YELL": {"lat": 44.4280, "lon": -110.5885}
}

# provides location data for each national park in our dataset

# %%
# Add comments
avg_temp_summary = []

# iterate through each park
for unit_code, coords in parks_info.items():
    lat, lon = coords['lat'], coords['lon']

    # create url for each park, this is not the request
    url = f"http://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&appid={api_key}&units=imperial"

    # request the data and get the data if successful otherwise return a code in the 400s
    response = requests.get(url)

    if response.status_code == 200:
        forecast_data = response.json()
        forecast_list = forecast_data['list']

        # extract out date and time
        df_forecast = pd.DataFrame([{
            'datetime': item['dt_txt'],
            'temperature': item['main']['temp']
        } for item in forecast_list])  # FYI this will have performance issues if your data scales.

        # convert to a date in pandas
        df_forecast['datetime'] = pd.to_datetime(df_forecast['datetime'])

        # for the five days of weather data, create 5 day avg.
        df_forecast['date'] = df_forecast['datetime'].dt.date
        daily_avg_temps = df_forecast.groupby('date')['temperature'].mean().reset_index()

        #
        five_day_avg_temp = daily_avg_temps['temperature'].mean()

         #
        avg_temp_summary.append({'UNITCODE': unit_code, 'five_day_avg_temp': five_day_avg_temp})

    else:
        print(f"Failed to retrieve data for {unit_code}: Status code", response.status_code)


df_avg_temp_summary = pd.DataFrame(avg_temp_summary) # Create a DataFrame from the summary list


merged_df = merged_df.merge(df_avg_temp_summary, on='UNITCODE', how='left') # Merge the summary DataFrame with your existing merged_df on UNITCODE


merged_df.head()
# Out:
#    Unnamed: 0 UNITCODE  Image                                      Location  \
# 0          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 1          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 2          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 3          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 4          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
#
#   Date established as park[7][12]                   Area (2021)[13]  \
# 0                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 1                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 2                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 3                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 4                       11-May-10  1,013,126.39 acres (4,100.0 km2)
#
#    Recreation visitors (2021)[11]  \
# 0                         3081656
# 1                         3081656
# 2                         3081656
# 3                         3081656
# 4                         3081656
#
#                                          Description  OBJECTID  \
# 0  The U.S. half of Waterton-Glacier Internationa...       359
# 1  The U.S. half of Waterton-Glacier Internationa...       365
# 2  The U.S. half of Waterton-Glacier Internationa...       369
# 3  The U.S. half of Waterton-Glacier Internationa...       399
# 4  The U.S. half of Waterton-Glacier Internationa...       406
#
#                         TRLNAME TRLALTNAME                      MAPLABEL  \
# 0                  Quartz Creek        NaN                  Quartz Creek
# 1                Martha's Basin        NaN                Martha's Basin
# 2                   Piegan Pass        NaN                   Piegan Pass
# 3    North Shore Josephine Lake        NaN    North Shore Josephine Lake
# 4  Boulder Pass Campground Spur        NaN  Boulder Pass Campground Spur
#
#   TRLSTATUS TRLSURFACE               TRLTYPE            TRLCLASS  \
# 0  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 1  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 2  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 3  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 4  Existing      Earth  Standard Terra Trail  Class 3: Developed
#
#                                               TRLUSE       PUBLICDISPLAY  \
# 0                 Low Use / Low level of maintenance  Public Map Display
# 1  Moderate to High Use / Highest level of mainte...  Public Map Display
# 2  Moderate to High Use / Highest level of mainte...  Public Map Display
# 3  Moderate to High Use / Highest level of mainte...  Public Map Display
# 4  Moderate to High Use / Highest level of mainte...  Public Map Display
#
#      DATAACCESS  ACCESSNOTES ORIGINATOR               UNITNAME UNITTYPE  \
# 0  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 1  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 2  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 3  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 4  Unrestricted          NaN        NaN  Glacier National Park      NaN
#
#   GROUPCODE GROUPNAME REGIONCODE              CREATEDATE  \
# 0       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 1       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 2       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 3       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 4       NaN       NaN        IMR  2021/04/07 20:22:17+00
#
#                  EDITDATE     LINETYPE MAPMETHOD          MAPSOURCE  \
# 0  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 1  2021/08/06 19:51:05+00  Center line   Unknown         Garmin GPS
# 2  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 3  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 4  2021/08/06 19:51:05+00  Center line   Unknown  ESRI Imagery 2013
#
#   SOURCEDATE XYACCURACY                              GEOMETRYID FEATUREID  \
# 0        NaN    Unknown  {21BA9C26-62D8-49CB-8FFF-81229CC78E52}       NaN
# 1        NaN    Unknown  {0605BD1D-70C4-4D96-AA3F-03168D68A102}       NaN
# 2        NaN    Unknown  {8FEC488C-33AC-4BDA-BBF6-27E4A421C01F}       NaN
# 3        NaN    Unknown  {F11E64B8-0023-4FDE-AB19-7D5752721FA6}       NaN
# 4        NaN    Unknown  {55EA0D6E-8F38-41BC-A87A-273F4D4FAA6E}       NaN
#
#   FACLOCID FACASSETID IMLOCID OBSERVABLE ISEXTANT OPENTOPUBLIC  ALTLANGNAME  \
# 0      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 1      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 2      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 3      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 4      NaN        NaN     NaN    Unknown     True      Unknown          NaN
#
#    ALTLANG SEASONAL SEASDESC             MAINTAINER NOTES  \
# 0      NaN  Unknown      NaN  National Park Service   NaN
# 1      NaN  Unknown      NaN  National Park Service   NaN
# 2      NaN  Unknown      NaN  National Park Service   NaN
# 3      NaN  Unknown      NaN  National Park Service   NaN
# 4      NaN  Unknown      NaN  National Park Service   NaN
#
#                             StagingTable  ShapeSTLength  five_day_avg_temp
# 0  STAGING_IMR_TRAILS_ALL_20240213004910       0.120064           11.00425
# 1  STAGING_IMR_TRAILS_ALL_20240213004910       0.016570           11.00425
# 2  STAGING_IMR_TRAILS_ALL_20240213004910       0.013829           11.00425
# 3  STAGING_IMR_TRAILS_ALL_20240213004910       0.006610           11.00425
# 4  STAGING_IMR_TRAILS_ALL_20240213004910       0.002319           11.00425

# %% [markdown]
# **3) Why are the values in five_day_avg_temp repeated?**

# %% [markdown]
# * because its a one -> many relationship

# %%
merged_df['UNITCODE'].value_counts()

len(merged_df)
# Out:
# 3659

# %% [markdown]
# **4) What is the difference between an inner (what we did the first time) and left merge (what we just did)?**

# %% [markdown]
# * Inner Join: All common records between the dataframes even on the specified column
# * Left Join: All records in the left table are returned even if there isn't a matching record in the other table
#
# *** In Pandas NULLs are matched with eachother unlike in SQL ***

# %%
merged_df.head()
# Out:
#    Unnamed: 0 UNITCODE  Image                                      Location  \
# 0          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 1          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 2          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 3          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
# 4          21     GLAC    NaN  Montana48°48′N 114°00′W﻿ / ﻿48.80°N 114.00°W
#
#   Date established as park[7][12]                   Area (2021)[13]  \
# 0                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 1                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 2                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 3                       11-May-10  1,013,126.39 acres (4,100.0 km2)
# 4                       11-May-10  1,013,126.39 acres (4,100.0 km2)
#
#    Recreation visitors (2021)[11]  \
# 0                         3081656
# 1                         3081656
# 2                         3081656
# 3                         3081656
# 4                         3081656
#
#                                          Description  OBJECTID  \
# 0  The U.S. half of Waterton-Glacier Internationa...       359
# 1  The U.S. half of Waterton-Glacier Internationa...       365
# 2  The U.S. half of Waterton-Glacier Internationa...       369
# 3  The U.S. half of Waterton-Glacier Internationa...       399
# 4  The U.S. half of Waterton-Glacier Internationa...       406
#
#                         TRLNAME TRLALTNAME                      MAPLABEL  \
# 0                  Quartz Creek        NaN                  Quartz Creek
# 1                Martha's Basin        NaN                Martha's Basin
# 2                   Piegan Pass        NaN                   Piegan Pass
# 3    North Shore Josephine Lake        NaN    North Shore Josephine Lake
# 4  Boulder Pass Campground Spur        NaN  Boulder Pass Campground Spur
#
#   TRLSTATUS TRLSURFACE               TRLTYPE            TRLCLASS  \
# 0  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 1  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 2  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 3  Existing      Earth  Standard Terra Trail  Class 3: Developed
# 4  Existing      Earth  Standard Terra Trail  Class 3: Developed
#
#                                               TRLUSE       PUBLICDISPLAY  \
# 0                 Low Use / Low level of maintenance  Public Map Display
# 1  Moderate to High Use / Highest level of mainte...  Public Map Display
# 2  Moderate to High Use / Highest level of mainte...  Public Map Display
# 3  Moderate to High Use / Highest level of mainte...  Public Map Display
# 4  Moderate to High Use / Highest level of mainte...  Public Map Display
#
#      DATAACCESS  ACCESSNOTES ORIGINATOR               UNITNAME UNITTYPE  \
# 0  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 1  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 2  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 3  Unrestricted          NaN        NaN  Glacier National Park      NaN
# 4  Unrestricted          NaN        NaN  Glacier National Park      NaN
#
#   GROUPCODE GROUPNAME REGIONCODE              CREATEDATE  \
# 0       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 1       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 2       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 3       NaN       NaN        IMR  2021/04/07 20:22:17+00
# 4       NaN       NaN        IMR  2021/04/07 20:22:17+00
#
#                  EDITDATE     LINETYPE MAPMETHOD          MAPSOURCE  \
# 0  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 1  2021/08/06 19:51:05+00  Center line   Unknown         Garmin GPS
# 2  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 3  2021/08/06 19:51:05+00  Center line   Unknown    Trimble Pro XRS
# 4  2021/08/06 19:51:05+00  Center line   Unknown  ESRI Imagery 2013
#
#   SOURCEDATE XYACCURACY                              GEOMETRYID FEATUREID  \
# 0        NaN    Unknown  {21BA9C26-62D8-49CB-8FFF-81229CC78E52}       NaN
# 1        NaN    Unknown  {0605BD1D-70C4-4D96-AA3F-03168D68A102}       NaN
# 2        NaN    Unknown  {8FEC488C-33AC-4BDA-BBF6-27E4A421C01F}       NaN
# 3        NaN    Unknown  {F11E64B8-0023-4FDE-AB19-7D5752721FA6}       NaN
# 4        NaN    Unknown  {55EA0D6E-8F38-41BC-A87A-273F4D4FAA6E}       NaN
#
#   FACLOCID FACASSETID IMLOCID OBSERVABLE ISEXTANT OPENTOPUBLIC  ALTLANGNAME  \
# 0      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 1      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 2      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 3      NaN        NaN     NaN    Unknown     True      Unknown          NaN
# 4      NaN        NaN     NaN    Unknown     True      Unknown          NaN
#
#    ALTLANG SEASONAL SEASDESC             MAINTAINER NOTES  \
# 0      NaN  Unknown      NaN  National Park Service   NaN
# 1      NaN  Unknown      NaN  National Park Service   NaN
# 2      NaN  Unknown      NaN  National Park Service   NaN
# 3      NaN  Unknown      NaN  National Park Service   NaN
# 4      NaN  Unknown      NaN  National Park Service   NaN
#
#                             StagingTable  ShapeSTLength  five_day_avg_temp
# 0  STAGING_IMR_TRAILS_ALL_20240213004910       0.120064           11.00425
# 1  STAGING_IMR_TRAILS_ALL_20240213004910       0.016570           11.00425
# 2  STAGING_IMR_TRAILS_ALL_20240213004910       0.013829           11.00425
# 3  STAGING_IMR_TRAILS_ALL_20240213004910       0.006610           11.00425
# 4  STAGING_IMR_TRAILS_ALL_20240213004910       0.002319           11.00425

# %% [markdown]
# ## **Part D) Build a Park \& Trail Recommender!**

# %%
def park_recommender(activity, state, n=5, popular=True):
    # filter down to parks that start with requested state
    state_parks = merged_df[merged_df['Location'].str.startswith(state, na=False)]

    # filter by trailer use
    activity_parks = state_parks[state_parks['TRLUSE'].str.contains(activity, case=False, na=False)]

    # sort by populatrity 
    activity_parks = activity_parks.sort_values(
        'Recreation visitors (2021)[11]',
        ascending=not popular
    )

    # return top results
    top_parks = activity_parks.head(n)

    return top_parks[['UNITCODE', 'Location', 'TRLNAME', 'five_day_avg_temp', 'TRLSURFACE']]

# %%
recommendations = park_recommender("hik", "Colorado", n=10)
recommendations
# Out:
#      UNITCODE                                       Location  \
# 1076     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1168     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1166     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1165     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1164     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1163     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1162     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1161     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1160     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
# 1159     ROMO  Colorado40°24′N 105°35′W﻿ / ﻿40.40°N 105.58°W
#
#                                                 TRLNAME  five_day_avg_temp  \
# 1076                                     New Storm Pass             7.0805
# 1168                               The Pool/Odessa Lake             7.0805
# 1166                         Moraine Park Museum Trails             7.0805
# 1165   Fall River - Little Horseshoe Park Complex Trail             7.0805
# 1164  Continental Divide National Scenic Trail - Bow...             7.0805
# 1163                              Upper Lawn Lake Trail             7.0805
# 1162                              North Boundary, Upper             7.0805
# 1161                         Old Entrance Livery Trails             7.0805
# 1160                         Moraine Park Museum Trails             7.0805
# 1159                       North Inlet-Flattop Junction             7.0805
#
#      TRLSURFACE
# 1076      Earth
# 1168      Earth
# 1166      Earth
# 1165      Earth
# 1164      Earth
# 1163     Gravel
# 1162      Earth
# 1161      Earth
# 1160      Earth
# 1159      Earth

# %% [markdown]
# **1) Describe how the recommender works -- why have these particular trails been recommended?**

# %% [markdown]
# * its in colorado and contains hike

# %% [markdown]
# **2) Does this recommender suit the needs of our client (based on the data we wanted to collect from them)? Explain.**

# %% [markdown]
# * Not really, could be more detailed...
# * need more information on type of difficulty, trail conditions, current weather conditions (is there snow).

# %% [markdown]
# **3) How can we improve our approach? Should we be asking different questions in our survey? Trying to source different data? Trying to change our recommender function?**

# %% [markdown]
# * Change it to only show what parks contain that information and show how many trails provide the requirements at each park
# * current ground conditions (is there snow)
# * preference for weather temperature
# * distance/travel time from them
# * could actually use the weather data
